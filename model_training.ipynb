# %% [markdown]
# <a href="https://colab.research.google.com/github/treyschulman/CNN_design_for_AD/blob/master/model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CNN Alzheimer's MRI Classifier Replication - Colab Setup Notebook

# ==============================
# 📌 Step 0: Install Libraries
# ==============================
# !pip install pyyaml==6.0.1
# !pip install --upgrade torch torchvision torchaudio
# !pip install visdom
# !pip install pydot
# !pip install scipy==1.10.1

# %%
# ==============================
# 📌 Step 1: Mount Google Drive
# ==============================
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ==============================
# 📌 Step 2: Clone GitHub Repository (If not already cloned)
# ==============================
# %cd /content/drive/MyDrive/project # this relies on having the path pre-created
# !git clone https://github.com/treyschulman/CNN_design_for_AD.git
# %cd CNN_design_for_AD
# Out:
# /content/drive/.shortcut-targets-by-id/1XiZJoXj-dHNpweOgKYei9TyXjcahYTP7/project
# /content/drive/.shortcut-targets-by-id/1XiZJoXj-dHNpweOgKYei9TyXjcahYTP7/project/CNN_design_for_AD

# %%
# ==============================
# 📌 Step 3: Pull Latest Updates (If Repo Already Exists)
# ==============================
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 943 bytes | 31.00 KiB/s, done.
# From https://github.com/treyschulman/CNN_design_for_AD
#    bdf91d4..3e7f094  master     -> origin/master
# Updating bdf91d4..3e7f094
# Fast-forward
#  config.yaml | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# Rename tsv files to match expected filenames
# import os

# dataset_files_path = '/content/drive/MyDrive/project/CNN_design_for_AD/datasets/files'

# rename_mapping = {
#     'train_diagnosis.tsv': 'Train_diagnosis_ADNI.tsv',
#     'val_diagnosis.tsv': 'Val_diagnosis_ADNI.tsv',
#     'test_diagnosis.tsv': 'Test_diagnosis_ADNI.tsv',
#     'train_oasis.tsv': 'Train_ADNI.tsv',
#     'val_oasis.tsv': 'Val_ADNI.tsv',
#     'test_oasis.tsv': 'Test_ADNI.tsv',
# }

# for old_name, new_name in rename_mapping.items():
#     old_path = os.path.join(dataset_files_path, old_name)
#     new_path = os.path.join(dataset_files_path, new_name)
#     if os.path.exists(old_path):
#         os.rename(old_path, new_path)
#         print(f"✅ Renamed {old_name} -> {new_name}")
#     else:
#         print(f"⚠️ {old_name} not found (skipping)")

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"✅ Torch Device: {device}")
if device.type == 'cuda':
    print(f"GPU Model: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ No GPU detected - training will be very slow.")
# Out:
# ✅ Torch Device: cuda
# GPU Model: Tesla T4

# %%
# import pandas as pd

# # === Config paths ===
# scan_dir = "/content/drive/MyDrive/project/dir_to_scans/subjects/"
# tsv_path = "/content/drive/MyDrive/project/CNN_design_for_AD/datasets/files/participant.tsv"

# # === Load TSV and extract subject IDs ===
# tsv = pd.read_csv(tsv_path, sep='\t')
# subjects = tsv['participant_id'].tolist()

# # === Check for missing .nii.gz files ===
# missing = []
# for subj in subjects:
#     expected_file = f"{subj}_T1w.nii.gz"
#     if not os.path.exists(os.path.join(scan_dir, expected_file)):
#         missing.append(expected_file)

# # === Report ===
# if missing:
#     print(f"⚠️ Missing {len(missing)} scan(s):")
#     for m in missing:
#         print(" -", m)
# else:
#     print("✅ All scans found.")

# %%
# ==============================
# 📌 Step 5: Launch Training
# ==============================
# !python main.py --config /config
# Out:
# has module!
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# In total  163  patients in training set
# Epoch: [0][0/40]	Time 3.536 (3.536)	Data 1.518 (1.518)	Loss 1.1029 (1.1029)	Accuracy 25.000
# Epoch: [0][10/40]	Time 0.950 (1.155)	Data 0.016 (0.142)	Loss 0.9697 (1.0543)	Accuracy 75.000
# Epoch: [0][20/40]	Time 0.940 (1.050)	Data 0.000 (0.075)	Loss 0.8845 (1.0006)	Accuracy 25.000
# Epoch: [0][30/40]	Time 0.972 (1.024)	Data 0.001 (0.052)	Loss 0.7307 (0.9412)	Accuracy 75.000
# ...

# %%
# ==============================
# 📌 Step 6 (Optional): Resume Training if Colab Disconnects
# ==============================
print("\n✅ If session crashes or disconnects, run this command to resume training from last checkpoint:")
# !python main.py --config /config --resume-from ./saved_model/oasis_experiment/latest_checkpoint.pth
